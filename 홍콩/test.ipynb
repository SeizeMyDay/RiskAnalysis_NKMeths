# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('HK_exports_to_korea_preprocessed.csv')
df
# Out:
#      Unnamed: 0        Year  HK_export_to_Korea
# 0             0  1972-01-01                  10
# 1             1  1972-02-01                  13
# 2             2  1972-03-01                  11
# 3             3  1972-04-01                  13
# 4             4  1972-05-01                  13
# ..          ...         ...                 ...
# 637         637  2025-02-01                4885
# 638         638  2025-03-01                5200
# 639         639  2025-04-01                4843
# 640         640  2025-05-01                4672
# 641         641  2025-06-01                4669
#
# [642 rows x 3 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#            Year  HK_export_to_Korea
# 0    1972-01-01                  10
# 1    1972-02-01                  13
# 2    1972-03-01                  11
# 3    1972-04-01                  13
# 4    1972-05-01                  13
# ..          ...                 ...
# 637  2025-02-01                4885
# 638  2025-03-01                5200
# 639  2025-04-01                4843
# 640  2025-05-01                4672
# 641  2025-06-01                4669
#
# [642 rows x 2 columns]

# %%
df.to_csv('HK_exports_to_korea_preprocessed.csv', index=False)

# %%
df = pd.read_csv('HK_exports_to_korea_preprocessed.csv')
df
# Out:
#            Year  HK_export_to_Korea
# 0    1972-01-01                  10
# 1    1972-02-01                  13
# 2    1972-03-01                  11
# 3    1972-04-01                  13
# 4    1972-05-01                  13
# ..          ...                 ...
# 637  2025-02-01                4885
# 638  2025-03-01                5200
# 639  2025-04-01                4843
# 640  2025-05-01                4672
# 641  2025-06-01                4669
#
# [642 rows x 2 columns]

# %%
fig = px.line(x = df['Year'], y = df['HK_export_to_Korea'])
fig.add_trace(go.Scatter(x = df['Year'], y = np.log(df['HK_export_to_Korea']), mode='lines', name='log'))
fig.add_trace(go.Scatter(x = df['Year'], y = np.log10(df['HK_export_to_Korea']), mode='lines', name='log10'))
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatterㄴ(x = df['Year'], y = np.log(df['HK_export_to_Korea']), mode='lines', name='log'))
fig.add_trace(go.Scatter(x = df['Year'], y = np.log10(df['HK_export_to_Korea']), mode='lines', name='log10'))
fig.show()

# %%
df['HK_export_to_Korea'].skew()
# Out:
# np.float64(0.4001897196844149)

# %%
np.log(df['HK_export_to_Korea']).skew()
# Out:
# np.float64(-1.023276958069322)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 # Breuch-Pagan test
#       2 from statsmodels.stats.diagnostic import het_breuschpagan
# ----> 4 bp_test = het_breuschpagan(model2.resid, model2.model.exog)
#       5 labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
#       6 for name, value in zip(labels, bp_test):
#
# NameError: name 'model2' is not defined
